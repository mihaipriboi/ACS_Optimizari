# %% [markdown]
# # Methods for minimizing a function

# %% [markdown]
# ### Dihotomic method

# %%
function dihotomic(f, a, b, eps, delta, max_iters = 1000000)
  i = 0
  while i < max_iters && abs(b - a) > eps
    lambda = (a + b) / 2 - delta
    mu = (a + b) / 2 + delta
    if f(lambda) < f(mu)
      b = mu
    else
      a = lambda
    end
    i += 1
  end

  if abs(b - a) < eps
    res = (a + b) / 2
    return a, b, res, f(res)
  else
    error("Maximum iterations reached without convergence.")
  end
end
# Out:
# dihotomic (generic function with 2 methods)

# %% [markdown]
# ### Binary search on derivative of concave function

# %%
# Binary search for point where df/dx = 0
function dx_bs_min(f, a, b, eps, dx_eps, max_iters = 1000000)
  left = a
  right = b
  
  while(right - left) > eps && max_iters > 0
    mid = (left + right) / 2.0
    df = f(mid) - f(mid - dx_eps)
    
    if df < 0
      left = mid
    else
      right = mid
    end

    max_iters -= 1
  end
  
  res = (left + right) / 2.0
  return left, right, res, f(res)
end
# Out:
# dx_bs_min (generic function with 2 methods)

# %% [markdown]
# ### Golden section method

# %%
function golden_section(f, a, b, eps, alpha, max_iters = 1000000)
  lambda = a + (1 - alpha) * (b - a)
  mu = a + alpha * (b - a)
  f_lambda = f(lambda)
  f_mu = f(mu)

  while abs(b - a) > eps && max_iters > 0
    if f_lambda >= f_mu
      a = lambda
      lambda = mu
      f_lambda = f_mu
      mu = a + alpha * (b - a)
      f_mu = f(mu)
    else
      b = mu
      mu = lambda
      f_mu = f_lambda
      lambda = a + (1 - alpha) * (b - a)
      f_lambda = f(lambda)
    end

    max_iters -= 1
  end

  res = (a + b) / 2.0
  return a, b, res, f(res)
end
# Out:
# golden_section (generic function with 2 methods)

# %% [markdown]
# ### Fibonacci method

# %%
function fibonacci(n)
  if n > 70
    return fibonacci_exact(n)
  else
    return fibonacci_approx(n)
  end
end

function fibonacci_exact(n)
  if n <= 0
    return 0
  elseif n == 1
    return 1
  end
  
  a, b = 0, 1
  for _ in 2:n
    a, b = b, a + b
  end
  
  return b
end

function fibonacci_approx(n)
  phi = (1 + sqrt(5)) / 2
  return round(Int, (phi^n - (-phi)^(-n)) / sqrt(5))
end

function fibonacci_search(f, a, b, eps, max_iters = 1000000)
  # Fn = (phi^n - (-phi^(-n))) / sqrt(5) > (b1 - a1) / eps
  phi = (1 + sqrt(5)) / 2
  target = (b - a) / eps
  n = ceil(Int, log(target * sqrt(5)) / log(phi))
  
  n = min(n, max_iters)

  lambda = a + (b - a) * fibonacci(n - 2) / fibonacci(n)
  miu = a + (b - a) * fibonacci(n - 1) / fibonacci(n)
  f_lambda = f(lambda)
  f_miu = f(miu)

  for k in 1:n-2
    if f_lambda >= f_miu
      a = lambda
      lambda = miu
      f_lambda = f_miu
      miu = a + (b - a) * fibonacci(n - k - 1) / fibonacci(n - k)
      f_miu = f(miu)
    else
      b = miu
      miu = lambda
      f_miu = f_lambda
      lambda = a + (b - a) * fibonacci(n - k - 2) / fibonacci(n - k)
      f_lambda = f(lambda)
    end
  end

  miu = lambda + eps
  f_miu = f(miu)

  if f_lambda >= f_miu
    a = lambda
  else
    b = miu
  end

  res = (a + b) / 2.0
  return a, b, res, f(res)
end
# Out:
# fibonacci_search (generic function with 2 methods)

# %% [markdown]
# ### Comparison and plotting of all methods

# %%
using Plots
using Printf
using BenchmarkTools

function calculate_min(f, a, b, eps = 1e-4)
  dh_a, dh_b, dh_min, dh_f_min = dihotomic(f, a, b, eps, eps / 10)
  bs_a, bs_b, bs_min, bs_f_min = dx_bs_min(f, a, b, eps, eps / 100)
  gm_a, gm_b, gm_min, gm_f_min = golden_section(f, a, b, eps, (sqrt(5) - 1) / 2)
  fib_a, fib_b, fib_min, fib_f_min = fibonacci_search(f, a, b, eps)

  @printf("Dihotomic method: ")
  @btime dihotomic($f, $a, $b, $eps, 1e-6)
  @printf("Minimum found in the interval: [%.4f, %.4f]\n", dh_a, dh_b)
  @printf("With x ~= %.4f and f(x) min ~= %.4f\n", dh_min, dh_f_min)
  
  @printf("\nBinary search method: ")
  @btime dx_bs_min($f, $a, $b, $eps, 1e-8)
  @printf("Minimum found in the interval: [%.4f, %.4f]\n", bs_a, bs_b)
  @printf("With x ~= %.4f and f(x) min ~= %.4f\n", bs_min, bs_f_min)

  @printf("\nGolden Section method: ")
  @btime golden_section($f, $a, $b, $eps, (sqrt(5) - 1) / 2)
  @printf("Minimum found in the interval: [%.4f, %.4f]\n", gm_a, gm_b)
  @printf("With x ~= %.4f and f(x) min ~= %.4f\n", gm_min, gm_f_min)

  @printf("\nFibonacci Search method: ")
  @btime fibonacci_search($f, $a, $b, $eps)
  @printf("Minimum found in the interval: [%.4f, %.4f]\n", fib_a, fib_b)
  @printf("With x ~= %.4f and f(x) min ~= %.4f\n", fib_min, fib_f_min)

  # Plot the function and mark the findings
  x = a:0.01:b
  y = f.(x)
  p = plot(x, y, label="f(x)", xlabel="x", ylabel="f(x)")

  annotate!(p, a, maximum(y), text(" Min: $(round(gm_f_min, digits=4)) at x ≈ $(round(gm_min, digits=4))", :left, 10))
  
  return p
end
# Out:
# calculate_min (generic function with 2 methods)

# %% [markdown]
# ### Results for different functions and intervals

# %%
functions = [
  (name="f(x) = x⁴ + x³ + 5x² + x + 2",   f = x -> x^4 + x^3 + 5x^2 + x + 2,     a = -3.0, b = 3.0),
  (name="f(x) = 5x² + x + 16",            f = x -> 5x^2 + x + 16,                a = -4.0, b = 4.0),
  (name="f(x) = sin(x) - cos(x)",         f = x -> sin(x) - cos(x),              a = -2.0, b = 2.0),
  (name="f(x) = eˣ - cos(x) - 5sin(x)",   f = x -> exp(x) - cos(x) - 5sin(x),    a = -7.0, b = -3.0),
  (name="f(x) = x² - x*cos(x)",           f = x -> x^2 - x*cos(x),               a = -3.0, b = 4.0),
  (name="f(x) = 5x³ + 2x² - 1",           f = x -> 5x^3 + 2x^2 - 1,              a = -7.0, b = 3.0),
  (name="f(x) = 5x² + x - 1",             f = x -> 5x^2 + x - 1,                 a = -3.0, b = 3.0)
]

all_plots = []

for fn in functions
  println("\n" * "-"^40)
  println("EVALUATING: $(fn.name)")
  println("-"^40)
  
  p = calculate_min(fn.f, fn.a, fn.b, 1e-3)
  
  title!(p, fn.name) 
  
  push!(all_plots, p)
end

n_cols = 2
n_rows = ceil(Int, length(functions) / n_cols)

plot(all_plots..., layout=(n_rows, n_cols), size=(900, 300 * n_rows))
# Out:
# ----------------------------------------
# EVALUATING: f(x) = x⁴ + x³ + 5x² + x + 2
# ----------------------------------------
# Dihotomic method:   356.052 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1034, -0.1024]
# With x ~= -0.1029 and f(x) min ~= 1.9491
#
# Binary search method:   309.221 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1033, -0.1025]
# With x ~= -0.1029 and f(x) min ~= 1.9491
#
# Golden Section method:   142.855 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1031, -0.1025]
# With x ~= -0.1028 and f(x) min ~= 1.9491
#
# Fibonacci Search method:   1.192 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1024, -0.1014]
# With x ~= -0.1019 and f(x) min ~= 1.9491
#
# ----------------------------------------
# EVALUATING: f(x) = 5x² + x + 16
# ----------------------------------------
# Dihotomic method:   89.585 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1002, -0.0995]
# With x ~= -0.0999 and f(x) min ~= 15.9500
#
# Binary search method:   92.439 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1006, -0.0996]
# With x ~= -0.1001 and f(x) min ~= 15.9500
#
# Golden Section method:   38.511 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1004, -0.0995]
# With x ~= -0.1000 and f(x) min ~= 15.9500
#
# Fibonacci Search method:   1.067 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1001, -0.0991]
# With x ~= -0.0996 and f(x) min ~= 15.9500
#
# ----------------------------------------
# EVALUATING: f(x) = sin(x) - cos(x)
# ----------------------------------------
# Dihotomic method:   313.561 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.7857, -0.7850]
# With x ~= -0.7854 and f(x) min ~= -1.4142
#
# Binary search method:   312.225 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.7861, -0.7852]
# With x ~= -0.7856 and f(x) min ~= -1.4142
#
# Golden Section method:   220.042 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.7856, -0.7849]
# With x ~= -0.7853 and f(x) min ~= -1.4142
#
# Fibonacci Search method:   1.192 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.7850, -0.7840]
# With x ~= -0.7845 and f(x) min ~= -1.4142
#
# ----------------------------------------
# EVALUATING: f(x) = eˣ - cos(x) - 5sin(x)
# ----------------------------------------
# Dihotomic method:   512.359 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-4.9117, -4.9110]
# With x ~= -4.9114 and f(x) min ~= -5.0917
#
# Binary search method:   516.271 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-4.9121, -4.9111]
# With x ~= -4.9116 and f(x) min ~= -5.0917
#
# Golden Section method:   362.183 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-4.9116, -4.9109]
# With x ~= -4.9112 and f(x) min ~= -5.0917
#
# Fibonacci Search method:   1.376 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-4.9115, -4.9105]
# With x ~= -4.9110 and f(x) min ~= -5.0917
#
# ----------------------------------------
# EVALUATING: f(x) = x² - x*cos(x)
# ----------------------------------------
# Dihotomic method:   244.685 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [0.3888, 0.3894]
# With x ~= 0.3891 and f(x) min ~= -0.2086
#
# Binary search method:   251.160 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [0.3889, 0.3898]
# With x ~= 0.3893 and f(x) min ~= -0.2086
#
# Golden Section method:   137.964 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [0.3885, 0.3892]
# With x ~= 0.3888 and f(x) min ~= -0.2086
#
# Fibonacci Search method:   1.241 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [0.3887, 0.3897]
# With x ~= 0.3892 and f(x) min ~= -0.2086
#
# ----------------------------------------
# EVALUATING: f(x) = 5x³ + 2x² - 1
# ----------------------------------------
# Dihotomic method:   113.933 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-7.0000, -6.9992]
# With x ~= -6.9996 and f(x) min ~= -1617.7136
#
# Binary search method:   120.430 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-7.0000, -6.9994]
# With x ~= -6.9997 and f(x) min ~= -1617.7843
#
# Golden Section method:   40.427 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-7.0000, -6.9993]
# With x ~= -6.9997 and f(x) min ~= -1617.7663
#
# Fibonacci Search method:   1.084 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-7.0000, -6.9990]
# With x ~= -6.9995 and f(x) min ~= -1617.6465
#
# ----------------------------------------
# EVALUATING: f(x) = 5x² + x - 1
# ----------------------------------------
# Dihotomic method:   89.275 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1004, -0.0995]
# With x ~= -0.1000 and f(x) min ~= -1.0500
#
# Binary search method:   92.463 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1003, -0.0996]
# With x ~= -0.1000 and f(x) min ~= -1.0500
#
# Golden Section method:   42.814 ns (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.1004, -0.0998]
# With x ~= -0.1001 and f(x) min ~= -1.0500
#
# Fibonacci Search method:   1.008 μs (0 allocations: 0 bytes)
# Minimum found in the interval: [-0.0998, -0.0988]
# With x ~= -0.0993 and f(x) min ~= -1.0500
